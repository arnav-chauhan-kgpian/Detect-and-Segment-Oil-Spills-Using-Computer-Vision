# %% [markdown]
# <a href="https://colab.research.google.com/github/arnav-chauhan-kgpian/Detect-and-Segment-Oil-Spills-Using-Computer-Vision/blob/main/Text_Mining_Project_Scraping_ArXiv_Articles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# category and total number of articles
ARXIV_FIELDS = {
    # Computer Science
    "cs": 10000
}

# %%
ARXIV_BASE_URL = "https://arxiv.org/list/"
ARXIV_ABS_URL = "https://arxiv.org/abs/"

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def generate_arxiv_pages(fields):
    pages = {}

    for category, total_articles in fields.items():
        # Generating URLs based on the category and total number of articles
        category_pages = []
        for skip in range(0, total_articles, 25):
            page = f"{ARXIV_BASE_URL}{category}/23?skip={skip}&show=25"
            category_pages.append(page)

        pages[category] = category_pages

    return pages

# %%
arxiv_pages = generate_arxiv_pages(ARXIV_FIELDS)

# %%
total_pages = 0
for category, category_pages in arxiv_pages.items():
    print(f"{category}:")
    length = len(category_pages)
    print(length)
    total_pages += length
print("total pages: ", total_pages)
# Out:
# cs:
# 400
# total pages:  400

# %%
def extract_ids(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    dl_tags = soup.find_all('dl')
    extracted_ids = []
    for dl_tag in dl_tags:
        dt_tags = dl_tag.find_all('dt')
        for dt_tag in dt_tags:
            # Iterate over all children of dt_tag
            for child in dt_tag.children:
                if getattr(child, 'name', None) == 'a' and child.get('title', '').lower() == 'abstract':
                    href_attr = child.get('href')
                    if href_attr:
                        id_value = href_attr.split('/')[-1]
                        extracted_ids.append(id_value)
                    break  # Only one abstract link per dt
    return extracted_ids

# %%
def scrape_articles_ids(page_url):
    try:
        # Send an HTTP GET request to the URL
        response = requests.get(page_url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Extract Ids
            return extract_ids(response.content)
        else:
            print(f"Failed to retrieve HTML content. Status code: {response.status_code}")
            return None

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
def get_articles_ids(pages_urls):
    articles_ids = {}
    for category, pages_urls in arxiv_pages.items():
        ids = []
        total_pages = len(pages_urls)
        print(f"\nProcessing category: {category} ({total_pages} pages)")
        try:
            for i, page_url in enumerate(pages_urls, 1):
                page_ids = scrape_articles_ids(page_url)
                if page_ids:
                    ids += page_ids
                print(f"  Page {i}/{total_pages} for {category}: {len(ids)} IDs collected so far")
            articles_ids[category] = ids
        except Exception as e:
            print(f"An error occurred in category '{category}': {e}")

        print(f"Finished {category}: {len(ids)} IDs collected.")

    return articles_ids

# %%
articles_ids = get_articles_ids(arxiv_pages)
# Out:
# Processing category: cs (400 pages)
#   Page 1/400 for cs: 50 IDs collected so far
#   Page 2/400 for cs: 100 IDs collected so far
#   Page 3/400 for cs: 150 IDs collected so far
#   Page 4/400 for cs: 200 IDs collected so far
#   Page 5/400 for cs: 250 IDs collected so far
#   Page 6/400 for cs: 300 IDs collected so far
#   Page 7/400 for cs: 350 IDs collected so far
#   Page 8/400 for cs: 400 IDs collected so far
#   Page 9/400 for cs: 450 IDs collected so far
#   Page 10/400 for cs: 500 IDs collected so far
#   Page 11/400 for cs: 550 IDs collected so far
#   Page 12/400 for cs: 600 IDs collected so far
#   Page 13/400 for cs: 650 IDs collected so far
#   Page 14/400 for cs: 700 IDs collected so far
#   Page 15/400 for cs: 750 IDs collected so far
#   Page 16/400 for cs: 800 IDs collected so far
#   Page 17/400 for cs: 850 IDs collected so far
#   Page 18/400 for cs: 900 IDs collected so far
#   Page 19/400 for cs: 950 IDs collected so far
#   Page 20/400 for cs: 1000 IDs collected so far
#   Page 21/400 for cs: 1050 IDs collected so far
#   Page 22/400 for cs: 1100 IDs collected so far
#   Page 23/400 for cs: 1150 IDs collected so far
#   Page 24/400 for cs: 1200 IDs collected so far
#   Page 25/400 for cs: 1250 IDs collected so far
#   Page 26/400 for cs: 1300 IDs collected so far
#   Page 27/400 for cs: 1350 IDs collected so far
#   Page 28/400 for cs: 1400 IDs collected so far
#   Page 29/400 for cs: 1450 IDs collected so far
#   Page 30/400 for cs: 1500 IDs collected so far
#   Page 31/400 for cs: 1550 IDs collected so far
#   Page 32/400 for cs: 1600 IDs collected so far
#   Page 33/400 for cs: 1650 IDs collected so far
#   Page 34/400 for cs: 1700 IDs collected so far
#   Page 35/400 for cs: 1750 IDs collected so far
#   Page 36/400 for cs: 1800 IDs collected so far
#   Page 37/400 for cs: 1850 IDs collected so far
#   Page 38/400 for cs: 1900 IDs collected so far
#   Page 39/400 for cs: 1950 IDs collected so far
#   Page 40/400 for cs: 2000 IDs collected so far
#   Page 41/400 for cs: 2050 IDs collected so far
#   Page 42/400 for cs: 2100 IDs collected so far
#   Page 43/400 for cs: 2150 IDs collected so far
#   Page 44/400 for cs: 2200 IDs collected so far
#   Page 45/400 for cs: 2250 IDs collected so far
#   Page 46/400 for cs: 2300 IDs collected so far
#   Page 47/400 for cs: 2350 IDs collected so far
#   Page 48/400 for cs: 2400 IDs collected so far
#   Page 49/400 for cs: 2450 IDs collected so far
#   Page 50/400 for cs: 2500 IDs collected so far
#   Page 51/400 for cs: 2550 IDs collected so far
#   Page 52/400 for cs: 2600 IDs collected so far
#   Page 53/400 for cs: 2650 IDs collected so far
#   Page 54/400 for cs: 2700 IDs collected so far
#   Page 55/400 for cs: 2750 IDs collected so far
#   Page 56/400 for cs: 2800 IDs collected so far
#   Page 57/400 for cs: 2850 IDs collected so far
#   Page 58/400 for cs: 2900 IDs collected so far
#   Page 59/400 for cs: 2950 IDs collected so far
#   Page 60/400 for cs: 3000 IDs collected so far
#   Page 61/400 for cs: 3050 IDs collected so far
#   Page 62/400 for cs: 3100 IDs collected so far
#   Page 63/400 for cs: 3150 IDs collected so far
#   Page 64/400 for cs: 3200 IDs collected so far
#   Page 65/400 for cs: 3250 IDs collected so far
#   Page 66/400 for cs: 3300 IDs collected so far
#   Page 67/400 for cs: 3350 IDs collected so far
#   Page 68/400 for cs: 3400 IDs collected so far
#   Page 69/400 for cs: 3450 IDs collected so far
#   Page 70/400 for cs: 3500 IDs collected so far
#   Page 71/400 for cs: 3550 IDs collected so far
#   Page 72/400 for cs: 3600 IDs collected so far
#   Page 73/400 for cs: 3650 IDs collected so far
#   Page 74/400 for cs: 3700 IDs collected so far
#   Page 75/400 for cs: 3750 IDs collected so far
#   Page 76/400 for cs: 3800 IDs collected so far
#   Page 77/400 for cs: 3850 IDs collected so far
#   Page 78/400 for cs: 3900 IDs collected so far
#   Page 79/400 for cs: 3950 IDs collected so far
#   Page 80/400 for cs: 4000 IDs collected so far
#   Page 81/400 for cs: 4050 IDs collected so far
#   Page 82/400 for cs: 4100 IDs collected so far
#   Page 83/400 for cs: 4150 IDs collected so far
#   Page 84/400 for cs: 4200 IDs collected so far
#   Page 85/400 for cs: 4250 IDs collected so far
#   Page 86/400 for cs: 4300 IDs collected so far
#   Page 87/400 for cs: 4350 IDs collected so far
#   Page 88/400 for cs: 4400 IDs collected so far
#   Page 89/400 for cs: 4450 IDs collected so far
#   Page 90/400 for cs: 4500 IDs collected so far
#   Page 91/400 for cs: 4550 IDs collected so far
#   Page 92/400 for cs: 4600 IDs collected so far
#   Page 93/400 for cs: 4650 IDs collected so far
#   Page 94/400 for cs: 4700 IDs collected so far
#   Page 95/400 for cs: 4750 IDs collected so far
#   Page 96/400 for cs: 4800 IDs collected so far
#   Page 97/400 for cs: 4850 IDs collected so far
#   Page 98/400 for cs: 4900 IDs collected so far
#   Page 99/400 for cs: 4950 IDs collected so far
#   Page 100/400 for cs: 5000 IDs collected so far
#   Page 101/400 for cs: 5050 IDs collected so far
#   Page 102/400 for cs: 5100 IDs collected so far
#   Page 103/400 for cs: 5150 IDs collected so far
#   Page 104/400 for cs: 5200 IDs collected so far
#   Page 105/400 for cs: 5250 IDs collected so far
#   Page 106/400 for cs: 5300 IDs collected so far
#   Page 107/400 for cs: 5350 IDs collected so far
#   Page 108/400 for cs: 5400 IDs collected so far
#   Page 109/400 for cs: 5450 IDs collected so far
#   Page 110/400 for cs: 5500 IDs collected so far
#   Page 111/400 for cs: 5550 IDs collected so far
#   Page 112/400 for cs: 5600 IDs collected so far
#   Page 113/400 for cs: 5650 IDs collected so far
#   Page 114/400 for cs: 5700 IDs collected so far
#   Page 115/400 for cs: 5750 IDs collected so far
#   Page 116/400 for cs: 5800 IDs collected so far
#   Page 117/400 for cs: 5850 IDs collected so far
#   Page 118/400 for cs: 5900 IDs collected so far
#   Page 119/400 for cs: 5950 IDs collected so far
#   Page 120/400 for cs: 6000 IDs collected so far
#   Page 121/400 for cs: 6050 IDs collected so far
#   Page 122/400 for cs: 6100 IDs collected so far
#   Page 123/400 for cs: 6150 IDs collected so far
#   Page 124/400 for cs: 6200 IDs collected so far
#   Page 125/400 for cs: 6250 IDs collected so far
#   Page 126/400 for cs: 6300 IDs collected so far
#   Page 127/400 for cs: 6350 IDs collected so far
#   Page 128/400 for cs: 6400 IDs collected so far
#   Page 129/400 for cs: 6450 IDs collected so far
#   Page 130/400 for cs: 6500 IDs collected so far
#   Page 131/400 for cs: 6550 IDs collected so far
#   Page 132/400 for cs: 6600 IDs collected so far
#   Page 133/400 for cs: 6650 IDs collected so far
#   Page 134/400 for cs: 6700 IDs collected so far
#   Page 135/400 for cs: 6750 IDs collected so far
#   Page 136/400 for cs: 6800 IDs collected so far
#   Page 137/400 for cs: 6850 IDs collected so far
#   Page 138/400 for cs: 6900 IDs collected so far
#   Page 139/400 for cs: 6950 IDs collected so far
#   Page 140/400 for cs: 7000 IDs collected so far
#   Page 141/400 for cs: 7050 IDs collected so far
#   Page 142/400 for cs: 7100 IDs collected so far
#   Page 143/400 for cs: 7150 IDs collected so far
#   Page 144/400 for cs: 7200 IDs collected so far
#   Page 145/400 for cs: 7250 IDs collected so far
#   Page 146/400 for cs: 7300 IDs collected so far
#   Page 147/400 for cs: 7350 IDs collected so far
#   Page 148/400 for cs: 7400 IDs collected so far
#   Page 149/400 for cs: 7450 IDs collected so far
#   Page 150/400 for cs: 7500 IDs collected so far
#   Page 151/400 for cs: 7550 IDs collected so far
#   Page 152/400 for cs: 7600 IDs collected so far
#   Page 153/400 for cs: 7650 IDs collected so far
#   Page 154/400 for cs: 7700 IDs collected so far
#   Page 155/400 for cs: 7750 IDs collected so far
#   Page 156/400 for cs: 7800 IDs collected so far
#   Page 157/400 for cs: 7850 IDs collected so far
#   Page 158/400 for cs: 7900 IDs collected so far
#   Page 159/400 for cs: 7950 IDs collected so far
#   Page 160/400 for cs: 8000 IDs collected so far
#   Page 161/400 for cs: 8050 IDs collected so far
#   Page 162/400 for cs: 8100 IDs collected so far
#   Page 163/400 for cs: 8150 IDs collected so far
#   Page 164/400 for cs: 8200 IDs collected so far
#   Page 165/400 for cs: 8250 IDs collected so far
#   Page 166/400 for cs: 8300 IDs collected so far
#   Page 167/400 for cs: 8350 IDs collected so far
#   Page 168/400 for cs: 8400 IDs collected so far
#   Page 169/400 for cs: 8450 IDs collected so far
#   Page 170/400 for cs: 8500 IDs collected so far
#   Page 171/400 for cs: 8550 IDs collected so far
#   Page 172/400 for cs: 8600 IDs collected so far
#   Page 173/400 for cs: 8650 IDs collected so far
#   Page 174/400 for cs: 8700 IDs collected so far
#   Page 175/400 for cs: 8750 IDs collected so far
#   Page 176/400 for cs: 8800 IDs collected so far
#   Page 177/400 for cs: 8850 IDs collected so far
#   Page 178/400 for cs: 8900 IDs collected so far
#   Page 179/400 for cs: 8950 IDs collected so far
#   Page 180/400 for cs: 9000 IDs collected so far
#   Page 181/400 for cs: 9050 IDs collected so far
#   Page 182/400 for cs: 9100 IDs collected so far
#   Page 183/400 for cs: 9150 IDs collected so far
#   Page 184/400 for cs: 9200 IDs collected so far
#   Page 185/400 for cs: 9250 IDs collected so far
#   Page 186/400 for cs: 9300 IDs collected so far
#   Page 187/400 for cs: 9350 IDs collected so far
#   Page 188/400 for cs: 9400 IDs collected so far
#   Page 189/400 for cs: 9450 IDs collected so far
#   Page 190/400 for cs: 9500 IDs collected so far
#   Page 191/400 for cs: 9550 IDs collected so far
#   Page 192/400 for cs: 9600 IDs collected so far
#   Page 193/400 for cs: 9650 IDs collected so far
#   Page 194/400 for cs: 9700 IDs collected so far
#   Page 195/400 for cs: 9750 IDs collected so far
#   Page 196/400 for cs: 9800 IDs collected so far
#   Page 197/400 for cs: 9850 IDs collected so far
#   Page 198/400 for cs: 9900 IDs collected so far
#   Page 199/400 for cs: 9950 IDs collected so far
#   Page 200/400 for cs: 10000 IDs collected so far
#   Page 201/400 for cs: 10050 IDs collected so far
#   Page 202/400 for cs: 10100 IDs collected so far
#   Page 203/400 for cs: 10150 IDs collected so far
#   Page 204/400 for cs: 10200 IDs collected so far
#   Page 205/400 for cs: 10250 IDs collected so far
#   Page 206/400 for cs: 10300 IDs collected so far
#   Page 207/400 for cs: 10350 IDs collected so far
#   Page 208/400 for cs: 10400 IDs collected so far
#   Page 209/400 for cs: 10450 IDs collected so far
#   Page 210/400 for cs: 10500 IDs collected so far
#   Page 211/400 for cs: 10550 IDs collected so far
#   Page 212/400 for cs: 10600 IDs collected so far
#   Page 213/400 for cs: 10650 IDs collected so far
#   Page 214/400 for cs: 10700 IDs collected so far
#   Page 215/400 for cs: 10750 IDs collected so far
#   Page 216/400 for cs: 10800 IDs collected so far
#   Page 217/400 for cs: 10850 IDs collected so far
#   Page 218/400 for cs: 10900 IDs collected so far
#   Page 219/400 for cs: 10950 IDs collected so far
#   Page 220/400 for cs: 11000 IDs collected so far
#   Page 221/400 for cs: 11050 IDs collected so far
#   Page 222/400 for cs: 11100 IDs collected so far
#   Page 223/400 for cs: 11150 IDs collected so far
#   Page 224/400 for cs: 11200 IDs collected so far
#   Page 225/400 for cs: 11250 IDs collected so far
#   Page 226/400 for cs: 11300 IDs collected so far
#   Page 227/400 for cs: 11350 IDs collected so far
#   Page 228/400 for cs: 11400 IDs collected so far
#   Page 229/400 for cs: 11450 IDs collected so far
#   Page 230/400 for cs: 11500 IDs collected so far
#   Page 231/400 for cs: 11550 IDs collected so far
#   Page 232/400 for cs: 11600 IDs collected so far
#   Page 233/400 for cs: 11650 IDs collected so far
#   Page 234/400 for cs: 11700 IDs collected so far
#   Page 235/400 for cs: 11750 IDs collected so far
#   Page 236/400 for cs: 11800 IDs collected so far
#   Page 237/400 for cs: 11850 IDs collected so far
#   Page 238/400 for cs: 11900 IDs collected so far
#   Page 239/400 for cs: 11950 IDs collected so far
#   Page 240/400 for cs: 12000 IDs collected so far
#   Page 241/400 for cs: 12050 IDs collected so far
#   Page 242/400 for cs: 12100 IDs collected so far
#   Page 243/400 for cs: 12150 IDs collected so far
#   Page 244/400 for cs: 12200 IDs collected so far
#   Page 245/400 for cs: 12250 IDs collected so far
#   Page 246/400 for cs: 12300 IDs collected so far
#   Page 247/400 for cs: 12350 IDs collected so far
#   Page 248/400 for cs: 12400 IDs collected so far
#   Page 249/400 for cs: 12450 IDs collected so far
#   Page 250/400 for cs: 12500 IDs collected so far
#   Page 251/400 for cs: 12550 IDs collected so far
#   Page 252/400 for cs: 12600 IDs collected so far
#   Page 253/400 for cs: 12650 IDs collected so far
#   Page 254/400 for cs: 12700 IDs collected so far
#   Page 255/400 for cs: 12750 IDs collected so far
#   Page 256/400 for cs: 12800 IDs collected so far
#   Page 257/400 for cs: 12850 IDs collected so far
#   Page 258/400 for cs: 12900 IDs collected so far
#   Page 259/400 for cs: 12950 IDs collected so far
#   Page 260/400 for cs: 13000 IDs collected so far
#   Page 261/400 for cs: 13050 IDs collected so far
#   Page 262/400 for cs: 13100 IDs collected so far
#   Page 263/400 for cs: 13150 IDs collected so far
#   Page 264/400 for cs: 13200 IDs collected so far
#   Page 265/400 for cs: 13250 IDs collected so far
#   Page 266/400 for cs: 13300 IDs collected so far
#   Page 267/400 for cs: 13350 IDs collected so far
#   Page 268/400 for cs: 13400 IDs collected so far
#   Page 269/400 for cs: 13450 IDs collected so far
#   Page 270/400 for cs: 13500 IDs collected so far
#   Page 271/400 for cs: 13550 IDs collected so far
#   Page 272/400 for cs: 13600 IDs collected so far
#   Page 273/400 for cs: 13650 IDs collected so far
#   Page 274/400 for cs: 13700 IDs collected so far
#   Page 275/400 for cs: 13750 IDs collected so far
#   Page 276/400 for cs: 13800 IDs collected so far
#   Page 277/400 for cs: 13850 IDs collected so far
#   Page 278/400 for cs: 13900 IDs collected so far
#   Page 279/400 for cs: 13950 IDs collected so far
#   Page 280/400 for cs: 14000 IDs collected so far
#   Page 281/400 for cs: 14050 IDs collected so far
#   Page 282/400 for cs: 14100 IDs collected so far
#   Page 283/400 for cs: 14150 IDs collected so far
#   Page 284/400 for cs: 14200 IDs collected so far
#   Page 285/400 for cs: 14250 IDs collected so far
#   Page 286/400 for cs: 14300 IDs collected so far
#   Page 287/400 for cs: 14350 IDs collected so far
#   Page 288/400 for cs: 14400 IDs collected so far
#   Page 289/400 for cs: 14450 IDs collected so far
#   Page 290/400 for cs: 14500 IDs collected so far
#   Page 291/400 for cs: 14550 IDs collected so far
#   Page 292/400 for cs: 14600 IDs collected so far
#   Page 293/400 for cs: 14650 IDs collected so far
#   Page 294/400 for cs: 14700 IDs collected so far
#   Page 295/400 for cs: 14750 IDs collected so far
#   Page 296/400 for cs: 14800 IDs collected so far
#   Page 297/400 for cs: 14850 IDs collected so far
#   Page 298/400 for cs: 14900 IDs collected so far
#   Page 299/400 for cs: 14950 IDs collected so far
#   Page 300/400 for cs: 15000 IDs collected so far
#   Page 301/400 for cs: 15050 IDs collected so far
#   Page 302/400 for cs: 15100 IDs collected so far
#   Page 303/400 for cs: 15150 IDs collected so far
#   Page 304/400 for cs: 15200 IDs collected so far
#   Page 305/400 for cs: 15250 IDs collected so far
#   Page 306/400 for cs: 15300 IDs collected so far
#   Page 307/400 for cs: 15350 IDs collected so far
#   Page 308/400 for cs: 15400 IDs collected so far
#   Page 309/400 for cs: 15450 IDs collected so far
#   Page 310/400 for cs: 15500 IDs collected so far
#   Page 311/400 for cs: 15550 IDs collected so far
#   Page 312/400 for cs: 15600 IDs collected so far
#   Page 313/400 for cs: 15650 IDs collected so far
#   Page 314/400 for cs: 15700 IDs collected so far
#   Page 315/400 for cs: 15750 IDs collected so far
#   Page 316/400 for cs: 15800 IDs collected so far
#   Page 317/400 for cs: 15850 IDs collected so far
#   Page 318/400 for cs: 15900 IDs collected so far
#   Page 319/400 for cs: 15950 IDs collected so far
#   Page 320/400 for cs: 16000 IDs collected so far
#   Page 321/400 for cs: 16050 IDs collected so far
#   Page 322/400 for cs: 16100 IDs collected so far
#   Page 323/400 for cs: 16150 IDs collected so far
#   Page 324/400 for cs: 16200 IDs collected so far
#   Page 325/400 for cs: 16250 IDs collected so far
#   Page 326/400 for cs: 16300 IDs collected so far
#   Page 327/400 for cs: 16350 IDs collected so far
#   Page 328/400 for cs: 16400 IDs collected so far
#   Page 329/400 for cs: 16450 IDs collected so far
#   Page 330/400 for cs: 16500 IDs collected so far
#   Page 331/400 for cs: 16550 IDs collected so far
#   Page 332/400 for cs: 16600 IDs collected so far
#   Page 333/400 for cs: 16650 IDs collected so far
#   Page 334/400 for cs: 16700 IDs collected so far
#   Page 335/400 for cs: 16750 IDs collected so far
#   Page 336/400 for cs: 16800 IDs collected so far
#   Page 337/400 for cs: 16850 IDs collected so far
#   Page 338/400 for cs: 16900 IDs collected so far
#   Page 339/400 for cs: 16950 IDs collected so far
#   Page 340/400 for cs: 17000 IDs collected so far
#   Page 341/400 for cs: 17050 IDs collected so far
#   Page 342/400 for cs: 17100 IDs collected so far
#   Page 343/400 for cs: 17150 IDs collected so far
#   Page 344/400 for cs: 17200 IDs collected so far
#   Page 345/400 for cs: 17250 IDs collected so far
#   Page 346/400 for cs: 17300 IDs collected so far
#   Page 347/400 for cs: 17350 IDs collected so far
#   Page 348/400 for cs: 17400 IDs collected so far
#   Page 349/400 for cs: 17450 IDs collected so far
#   Page 350/400 for cs: 17500 IDs collected so far
#   Page 351/400 for cs: 17550 IDs collected so far
#   Page 352/400 for cs: 17600 IDs collected so far
#   Page 353/400 for cs: 17650 IDs collected so far
#   Page 354/400 for cs: 17700 IDs collected so far
#   Page 355/400 for cs: 17750 IDs collected so far
#   Page 356/400 for cs: 17800 IDs collected so far
#   Page 357/400 for cs: 17850 IDs collected so far
#   Page 358/400 for cs: 17900 IDs collected so far
#   Page 359/400 for cs: 17950 IDs collected so far
#   Page 360/400 for cs: 18000 IDs collected so far
#   Page 361/400 for cs: 18050 IDs collected so far
#   Page 362/400 for cs: 18100 IDs collected so far
#   Page 363/400 for cs: 18150 IDs collected so far
#   Page 364/400 for cs: 18200 IDs collected so far
#   Page 365/400 for cs: 18250 IDs collected so far
#   Page 366/400 for cs: 18300 IDs collected so far
#   Page 367/400 for cs: 18350 IDs collected so far
#   Page 368/400 for cs: 18400 IDs collected so far
#   Page 369/400 for cs: 18450 IDs collected so far
#   Page 370/400 for cs: 18500 IDs collected so far
#   Page 371/400 for cs: 18550 IDs collected so far
#   Page 372/400 for cs: 18600 IDs collected so far
#   Page 373/400 for cs: 18650 IDs collected so far
#   Page 374/400 for cs: 18700 IDs collected so far
#   Page 375/400 for cs: 18750 IDs collected so far
#   Page 376/400 for cs: 18800 IDs collected so far
#   Page 377/400 for cs: 18850 IDs collected so far
#   Page 378/400 for cs: 18900 IDs collected so far
#   Page 379/400 for cs: 18950 IDs collected so far
#   Page 380/400 for cs: 19000 IDs collected so far
#   Page 381/400 for cs: 19050 IDs collected so far
#   Page 382/400 for cs: 19100 IDs collected so far
#   Page 383/400 for cs: 19150 IDs collected so far
#   Page 384/400 for cs: 19200 IDs collected so far
#   Page 385/400 for cs: 19250 IDs collected so far
#   Page 386/400 for cs: 19300 IDs collected so far
#   Page 387/400 for cs: 19350 IDs collected so far
#   Page 388/400 for cs: 19400 IDs collected so far
#   Page 389/400 for cs: 19450 IDs collected so far
#   Page 390/400 for cs: 19500 IDs collected so far
#   Page 391/400 for cs: 19550 IDs collected so far
#   Page 392/400 for cs: 19600 IDs collected so far
#   Page 393/400 for cs: 19650 IDs collected so far
#   Page 394/400 for cs: 19700 IDs collected so far
#   Page 395/400 for cs: 19750 IDs collected so far
#   Page 396/400 for cs: 19800 IDs collected so far
#   Page 397/400 for cs: 19850 IDs collected so far
#   Page 398/400 for cs: 19900 IDs collected so far
#   Page 399/400 for cs: 19950 IDs collected so far
#   Page 400/400 for cs: 20000 IDs collected so far
# Finished cs: 20000 IDs collected.

# %%
total_ids = 0
for _, ids in articles_ids.items():
  total_ids += len(ids)

print(f"total number of articles: {total_ids}")
# Out:
# total number of articles: 20000

# %%
def extract_summary(html_content):
    # Parse HTML content with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find all blockquote tags containing blockquote tags
    blockquote = soup.find_all('blockquote')

    content_without_span = ''.join(blockquote[0].find_all(string=True, recursive=False)).strip()

    return content_without_span

# %%
def scrape_article(id):
    article_url = ARXIV_ABS_URL + id
    try:
        # Send an HTTP GET request to the URL
        response = requests.get(article_url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Extract Ids
            return extract_summary(response.content)
        else:
            print(f"Failed to retrieve HTML content. Status code: {response.status_code}")
            return None

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
def extract_title(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    h1_tag = soup.find('h1', class_='title mathjax')
    if h1_tag:
        title_text = h1_tag.get_text(strip=True).replace('Title:', '').strip()
        return title_text
    return None

# %%
def scrape_title(id):
    article_url = ARXIV_ABS_URL + id
    try:
        response = requests.get(article_url)
        if response.status_code == 200:
            return extract_title(response.content)
        else:
            print(f"Failed to retrieve HTML content. Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
def create_dfs(articles_ids):
    list_dfs = []
    for category, ids in articles_ids.items():
        df_dicts_list = []
        total = len(ids)
        print(f"\nProcessing category: {category} ({total} articles)")
        for idx, id in enumerate(ids, 1):
            content = scrape_article(id)  # abstract
            title = scrape_title(id)      # title
            df_dicts_list.append({"id": id, "title": title, "abstract": content})
            if idx % 10 == 0 or idx == total:
                print(f"  {idx}/{total} articles processed for {category}")
        category_df = pd.DataFrame(df_dicts_list)
        list_dfs.append(category_df)
        print(f"Done for {category} category with shape: {category_df.shape}")
    return list_dfs

# %%
list_articles_dfs = create_dfs(articles_ids)
# Out:
# Processing category: cs (20000 articles)
#   10/20000 articles processed for cs
#   20/20000 articles processed for cs
#   30/20000 articles processed for cs
#   40/20000 articles processed for cs
#   50/20000 articles processed for cs
#   60/20000 articles processed for cs
#   70/20000 articles processed for cs
#   80/20000 articles processed for cs
#   90/20000 articles processed for cs
#   100/20000 articles processed for cs
#   110/20000 articles processed for cs
#   120/20000 articles processed for cs
#   130/20000 articles processed for cs
#   140/20000 articles processed for cs
#   150/20000 articles processed for cs
#   160/20000 articles processed for cs
#   170/20000 articles processed for cs
#   180/20000 articles processed for cs
#   190/20000 articles processed for cs
#   200/20000 articles processed for cs
#   210/20000 articles processed for cs
#   220/20000 articles processed for cs
#   230/20000 articles processed for cs
#   240/20000 articles processed for cs
#   250/20000 articles processed for cs
#   260/20000 articles processed for cs
#   270/20000 articles processed for cs
#   280/20000 articles processed for cs
#   290/20000 articles processed for cs
#   300/20000 articles processed for cs
#   310/20000 articles processed for cs
#   320/20000 articles processed for cs
#   330/20000 articles processed for cs
#   340/20000 articles processed for cs
#   350/20000 articles processed for cs
#   360/20000 articles processed for cs
#   370/20000 articles processed for cs
#   380/20000 articles processed for cs
#   390/20000 articles processed for cs
#   400/20000 articles processed for cs
#   410/20000 articles processed for cs
#   420/20000 articles processed for cs
#   430/20000 articles processed for cs
#   440/20000 articles processed for cs
#   450/20000 articles processed for cs
#   460/20000 articles processed for cs
#   470/20000 articles processed for cs
#   480/20000 articles processed for cs
#   490/20000 articles processed for cs
#   500/20000 articles processed for cs
#   510/20000 articles processed for cs
#   520/20000 articles processed for cs
#   530/20000 articles processed for cs
#   540/20000 articles processed for cs
#   550/20000 articles processed for cs
#   560/20000 articles processed for cs
#   570/20000 articles processed for cs
#   580/20000 articles processed for cs
#   590/20000 articles processed for cs
#   600/20000 articles processed for cs
#   610/20000 articles processed for cs
#   620/20000 articles processed for cs
#   630/20000 articles processed for cs
#   640/20000 articles processed for cs
#   650/20000 articles processed for cs
#   660/20000 articles processed for cs
#   670/20000 articles processed for cs
#   680/20000 articles processed for cs
#   690/20000 articles processed for cs
#   700/20000 articles processed for cs
#   710/20000 articles processed for cs
#   720/20000 articles processed for cs
#   730/20000 articles processed for cs
#   740/20000 articles processed for cs
#   750/20000 articles processed for cs
#   760/20000 articles processed for cs
#   770/20000 articles processed for cs
#   780/20000 articles processed for cs
#   790/20000 articles processed for cs
#   800/20000 articles processed for cs
#   810/20000 articles processed for cs
#   820/20000 articles processed for cs
#   830/20000 articles processed for cs
#   840/20000 articles processed for cs
#   850/20000 articles processed for cs
#   860/20000 articles processed for cs
#   870/20000 articles processed for cs
#   880/20000 articles processed for cs
#   890/20000 articles processed for cs
#   900/20000 articles processed for cs
#   910/20000 articles processed for cs
#   920/20000 articles processed for cs
#   930/20000 articles processed for cs
#   940/20000 articles processed for cs
#   950/20000 articles processed for cs
#   960/20000 articles processed for cs
#   970/20000 articles processed for cs
#   980/20000 articles processed for cs
#   990/20000 articles processed for cs
#   1000/20000 articles processed for cs
#   1010/20000 articles processed for cs
#   1020/20000 articles processed for cs
#   1030/20000 articles processed for cs
#   1040/20000 articles processed for cs
#   1050/20000 articles processed for cs
#   1060/20000 articles processed for cs
#   1070/20000 articles processed for cs
#   1080/20000 articles processed for cs
#   1090/20000 articles processed for cs
#   1100/20000 articles processed for cs
#   1110/20000 articles processed for cs
#   1120/20000 articles processed for cs
#   1130/20000 articles processed for cs
#   1140/20000 articles processed for cs
#   1150/20000 articles processed for cs
#   1160/20000 articles processed for cs
#   1170/20000 articles processed for cs
#   1180/20000 articles processed for cs
#   1190/20000 articles processed for cs
#   1200/20000 articles processed for cs
#   1210/20000 articles processed for cs
#   1220/20000 articles processed for cs
#   1230/20000 articles processed for cs
#   1240/20000 articles processed for cs
#   1250/20000 articles processed for cs
#   1260/20000 articles processed for cs
#   1270/20000 articles processed for cs
#   1280/20000 articles processed for cs
#   1290/20000 articles processed for cs
#   1300/20000 articles processed for cs
#   1310/20000 articles processed for cs
#   1320/20000 articles processed for cs
#   1330/20000 articles processed for cs
#   1340/20000 articles processed for cs
#   1350/20000 articles processed for cs
#   1360/20000 articles processed for cs
#   1370/20000 articles processed for cs
#   1380/20000 articles processed for cs
#   1390/20000 articles processed for cs
#   1400/20000 articles processed for cs
#   1410/20000 articles processed for cs
#   1420/20000 articles processed for cs
#   1430/20000 articles processed for cs
#   1440/20000 articles processed for cs
#   1450/20000 articles processed for cs
#   1460/20000 articles processed for cs
#   1470/20000 articles processed for cs
#   1480/20000 articles processed for cs
#   1490/20000 articles processed for cs
#   1500/20000 articles processed for cs
#   1510/20000 articles processed for cs
#   1520/20000 articles processed for cs
#   1530/20000 articles processed for cs
#   1540/20000 articles processed for cs
#   1550/20000 articles processed for cs
#   1560/20000 articles processed for cs
#   1570/20000 articles processed for cs
#   1580/20000 articles processed for cs
#   1590/20000 articles processed for cs
#   1600/20000 articles processed for cs
#   1610/20000 articles processed for cs
#   1620/20000 articles processed for cs
#   1630/20000 articles processed for cs
#   1640/20000 articles processed for cs
#   1650/20000 articles processed for cs
#   1660/20000 articles processed for cs
#   1670/20000 articles processed for cs
#   1680/20000 articles processed for cs
#   1690/20000 articles processed for cs
#   1700/20000 articles processed for cs
#   1710/20000 articles processed for cs
#   1720/20000 articles processed for cs
#   1730/20000 articles processed for cs
#   1740/20000 articles processed for cs
#   1750/20000 articles processed for cs
#   1760/20000 articles processed for cs
#   1770/20000 articles processed for cs
#   1780/20000 articles processed for cs
#   1790/20000 articles processed for cs
#   1800/20000 articles processed for cs
#   1810/20000 articles processed for cs
#   1820/20000 articles processed for cs
#   1830/20000 articles processed for cs
#   1840/20000 articles processed for cs
#   1850/20000 articles processed for cs
#   1860/20000 articles processed for cs
#   1870/20000 articles processed for cs
#   1880/20000 articles processed for cs
#   1890/20000 articles processed for cs
#   1900/20000 articles processed for cs
#   1910/20000 articles processed for cs
#   1920/20000 articles processed for cs
#   1930/20000 articles processed for cs
#   1940/20000 articles processed for cs
#   1950/20000 articles processed for cs
#   1960/20000 articles processed for cs
#   1970/20000 articles processed for cs
#   1980/20000 articles processed for cs
#   1990/20000 articles processed for cs
#   2000/20000 articles processed for cs
#   2010/20000 articles processed for cs
#   2020/20000 articles processed for cs
#   2030/20000 articles processed for cs
#   2040/20000 articles processed for cs
#   2050/20000 articles processed for cs
#   2060/20000 articles processed for cs
#   2070/20000 articles processed for cs
#   2080/20000 articles processed for cs
#   2090/20000 articles processed for cs
#   2100/20000 articles processed for cs
#   2110/20000 articles processed for cs
#   2120/20000 articles processed for cs
#   2130/20000 articles processed for cs
#   2140/20000 articles processed for cs
#   2150/20000 articles processed for cs
#   2160/20000 articles processed for cs
#   2170/20000 articles processed for cs
#   2180/20000 articles processed for cs
#   2190/20000 articles processed for cs
#   2200/20000 articles processed for cs
#   2210/20000 articles processed for cs
#   2220/20000 articles processed for cs
#   2230/20000 articles processed for cs
#   2240/20000 articles processed for cs
#   2250/20000 articles processed for cs
#   2260/20000 articles processed for cs
#   2270/20000 articles processed for cs
#   2280/20000 articles processed for cs
#   2290/20000 articles processed for cs
#   2300/20000 articles processed for cs
#   2310/20000 articles processed for cs
#   2320/20000 articles processed for cs
#   2330/20000 articles processed for cs
#   2340/20000 articles processed for cs
#   2350/20000 articles processed for cs
#   2360/20000 articles processed for cs
#   2370/20000 articles processed for cs
#   2380/20000 articles processed for cs
#   2390/20000 articles processed for cs
#   2400/20000 articles processed for cs
#   2410/20000 articles processed for cs
#   2420/20000 articles processed for cs
#   2430/20000 articles processed for cs
#   2440/20000 articles processed for cs
#   2450/20000 articles processed for cs
#   2460/20000 articles processed for cs
#   2470/20000 articles processed for cs
#   2480/20000 articles processed for cs
#   2490/20000 articles processed for cs
#   2500/20000 articles processed for cs
#   2510/20000 articles processed for cs
#   2520/20000 articles processed for cs
#   2530/20000 articles processed for cs
#   2540/20000 articles processed for cs
#   2550/20000 articles processed for cs
#   2560/20000 articles processed for cs
#   2570/20000 articles processed for cs
#   2580/20000 articles processed for cs
#   2590/20000 articles processed for cs
#   2600/20000 articles processed for cs
#   2610/20000 articles processed for cs
#   2620/20000 articles processed for cs
#   2630/20000 articles processed for cs
#   2640/20000 articles processed for cs
#   2650/20000 articles processed for cs
#   2660/20000 articles processed for cs
#   2670/20000 articles processed for cs
#   2680/20000 articles processed for cs
#   2690/20000 articles processed for cs
#   2700/20000 articles processed for cs
#   2710/20000 articles processed for cs
#   2720/20000 articles processed for cs
#   2730/20000 articles processed for cs
#   2740/20000 articles processed for cs
#   2750/20000 articles processed for cs
#   2760/20000 articles processed for cs
#   2770/20000 articles processed for cs
#   2780/20000 articles processed for cs
#   2790/20000 articles processed for cs
#   2800/20000 articles processed for cs
#   2810/20000 articles processed for cs
#   2820/20000 articles processed for cs
#   2830/20000 articles processed for cs
#   2840/20000 articles processed for cs
#   2850/20000 articles processed for cs
#   2860/20000 articles processed for cs
#   2870/20000 articles processed for cs
#   2880/20000 articles processed for cs
#   2890/20000 articles processed for cs
#   2900/20000 articles processed for cs
#   2910/20000 articles processed for cs
#   2920/20000 articles processed for cs
#   2930/20000 articles processed for cs
#   2940/20000 articles processed for cs
#   2950/20000 articles processed for cs
#   2960/20000 articles processed for cs
#   2970/20000 articles processed for cs
#   2980/20000 articles processed for cs
#   2990/20000 articles processed for cs
#   3000/20000 articles processed for cs
#   3010/20000 articles processed for cs
#   3020/20000 articles processed for cs
#   3030/20000 articles processed for cs
#   3040/20000 articles processed for cs
#   3050/20000 articles processed for cs
#   3060/20000 articles processed for cs
#   3070/20000 articles processed for cs
#   3080/20000 articles processed for cs
#   3090/20000 articles processed for cs
#   3100/20000 articles processed for cs
#   3110/20000 articles processed for cs
#   3120/20000 articles processed for cs
#   3130/20000 articles processed for cs
#   3140/20000 articles processed for cs
#   3150/20000 articles processed for cs
#   3160/20000 articles processed for cs
#   3170/20000 articles processed for cs
#   3180/20000 articles processed for cs
#   3190/20000 articles processed for cs
#   3200/20000 articles processed for cs
#   3210/20000 articles processed for cs
#   3220/20000 articles processed for cs
#   3230/20000 articles processed for cs
#   3240/20000 articles processed for cs
#   3250/20000 articles processed for cs
#   3260/20000 articles processed for cs
#   3270/20000 articles processed for cs
#   3280/20000 articles processed for cs
#   3290/20000 articles processed for cs
#   3300/20000 articles processed for cs
#   3310/20000 articles processed for cs
#   3320/20000 articles processed for cs
#   3330/20000 articles processed for cs
#   3340/20000 articles processed for cs
#   3350/20000 articles processed for cs
#   3360/20000 articles processed for cs
#   3370/20000 articles processed for cs
#   3380/20000 articles processed for cs
#   3390/20000 articles processed for cs
#   3400/20000 articles processed for cs
#   3410/20000 articles processed for cs
#   3420/20000 articles processed for cs
#   3430/20000 articles processed for cs
#   3440/20000 articles processed for cs
#   3450/20000 articles processed for cs
#   3460/20000 articles processed for cs
#   3470/20000 articles processed for cs
#   3480/20000 articles processed for cs
#   3490/20000 articles processed for cs
#   3500/20000 articles processed for cs
#   3510/20000 articles processed for cs
#   3520/20000 articles processed for cs
#   3530/20000 articles processed for cs
#   3540/20000 articles processed for cs
#   3550/20000 articles processed for cs
#   3560/20000 articles processed for cs
#   3570/20000 articles processed for cs
#   3580/20000 articles processed for cs
#   3590/20000 articles processed for cs
#   3600/20000 articles processed for cs
#   3610/20000 articles processed for cs
#   3620/20000 articles processed for cs
#   3630/20000 articles processed for cs
#   3640/20000 articles processed for cs
#   3650/20000 articles processed for cs
#   3660/20000 articles processed for cs
#   3670/20000 articles processed for cs
#   3680/20000 articles processed for cs
#   3690/20000 articles processed for cs
#   3700/20000 articles processed for cs
#   3710/20000 articles processed for cs
#   3720/20000 articles processed for cs
#   3730/20000 articles processed for cs
#   3740/20000 articles processed for cs
#   3750/20000 articles processed for cs
#   3760/20000 articles processed for cs
#   3770/20000 articles processed for cs
#   3780/20000 articles processed for cs
#   3790/20000 articles processed for cs
#   3800/20000 articles processed for cs
#   3810/20000 articles processed for cs
#   3820/20000 articles processed for cs
#   3830/20000 articles processed for cs
#   3840/20000 articles processed for cs
#   3850/20000 articles processed for cs
#   3860/20000 articles processed for cs
#   3870/20000 articles processed for cs
#   3880/20000 articles processed for cs
#   3890/20000 articles processed for cs
#   3900/20000 articles processed for cs
#   3910/20000 articles processed for cs
#   3920/20000 articles processed for cs
#   3930/20000 articles processed for cs
#   3940/20000 articles processed for cs
#   3950/20000 articles processed for cs
#   3960/20000 articles processed for cs
#   3970/20000 articles processed for cs
#   3980/20000 articles processed for cs
#   3990/20000 articles processed for cs
#   4000/20000 articles processed for cs
#   4010/20000 articles processed for cs
#   4020/20000 articles processed for cs
#   4030/20000 articles processed for cs
#   4040/20000 articles processed for cs
#   4050/20000 articles processed for cs
#   4060/20000 articles processed for cs
#   4070/20000 articles processed for cs
#   4080/20000 articles processed for cs
#   4090/20000 articles processed for cs
#   4100/20000 articles processed for cs
#   4110/20000 articles processed for cs
#   4120/20000 articles processed for cs
#   4130/20000 articles processed for cs
#   4140/20000 articles processed for cs
#   4150/20000 articles processed for cs
#   4160/20000 articles processed for cs
#   4170/20000 articles processed for cs
#   4180/20000 articles processed for cs
#   4190/20000 articles processed for cs
#   4200/20000 articles processed for cs
#   4210/20000 articles processed for cs
#   4220/20000 articles processed for cs
#   4230/20000 articles processed for cs
#   4240/20000 articles processed for cs
#   4250/20000 articles processed for cs
#   4260/20000 articles processed for cs
#   4270/20000 articles processed for cs
#   4280/20000 articles processed for cs
#   4290/20000 articles processed for cs
#   4300/20000 articles processed for cs
#   4310/20000 articles processed for cs
#   4320/20000 articles processed for cs
#   4330/20000 articles processed for cs
#   4340/20000 articles processed for cs
#   4350/20000 articles processed for cs
#   4360/20000 articles processed for cs
#   4370/20000 articles processed for cs
#   4380/20000 articles processed for cs
#   4390/20000 articles processed for cs
#   4400/20000 articles processed for cs
#   4410/20000 articles processed for cs
#   4420/20000 articles processed for cs
#   4430/20000 articles processed for cs
#   4440/20000 articles processed for cs
#   4450/20000 articles processed for cs
#   4460/20000 articles processed for cs
#   4470/20000 articles processed for cs
#   4480/20000 articles processed for cs
#   4490/20000 articles processed for cs
#   4500/20000 articles processed for cs
#   4510/20000 articles processed for cs
#   4520/20000 articles processed for cs
#   4530/20000 articles processed for cs
#   4540/20000 articles processed for cs
#   4550/20000 articles processed for cs
#   4560/20000 articles processed for cs
#   4570/20000 articles processed for cs
#   4580/20000 articles processed for cs
#   4590/20000 articles processed for cs
#   4600/20000 articles processed for cs
#   4610/20000 articles processed for cs
#   4620/20000 articles processed for cs
#   4630/20000 articles processed for cs
#   4640/20000 articles processed for cs
#   4650/20000 articles processed for cs
#   4660/20000 articles processed for cs
#   4670/20000 articles processed for cs
#   4680/20000 articles processed for cs
#   4690/20000 articles processed for cs
#   4700/20000 articles processed for cs
#   4710/20000 articles processed for cs
#   4720/20000 articles processed for cs
#   4730/20000 articles processed for cs
#   4740/20000 articles processed for cs
#   4750/20000 articles processed for cs
#   4760/20000 articles processed for cs
#   4770/20000 articles processed for cs
#   4780/20000 articles processed for cs
#   4790/20000 articles processed for cs
#   4800/20000 articles processed for cs
#   4810/20000 articles processed for cs
#   4820/20000 articles processed for cs
#   4830/20000 articles processed for cs
#   4840/20000 articles processed for cs
#   4850/20000 articles processed for cs
#   4860/20000 articles processed for cs
#   4870/20000 articles processed for cs
#   4880/20000 articles processed for cs
#   4890/20000 articles processed for cs
#   4900/20000 articles processed for cs
#   4910/20000 articles processed for cs
#   4920/20000 articles processed for cs
#   4930/20000 articles processed for cs
#   4940/20000 articles processed for cs
#   4950/20000 articles processed for cs
#   4960/20000 articles processed for cs
#   4970/20000 articles processed for cs
#   4980/20000 articles processed for cs
#   4990/20000 articles processed for cs
#   5000/20000 articles processed for cs
#   5010/20000 articles processed for cs
#   5020/20000 articles processed for cs
#   5030/20000 articles processed for cs
#   5040/20000 articles processed for cs
#   5050/20000 articles processed for cs
#   5060/20000 articles processed for cs
#   5070/20000 articles processed for cs
#   5080/20000 articles processed for cs
#   5090/20000 articles processed for cs
#   5100/20000 articles processed for cs
#   5110/20000 articles processed for cs
#   5120/20000 articles processed for cs
#   5130/20000 articles processed for cs
#   5140/20000 articles processed for cs
#   5150/20000 articles processed for cs
#   5160/20000 articles processed for cs
#   5170/20000 articles processed for cs
#   5180/20000 articles processed for cs
#   5190/20000 articles processed for cs
#   5200/20000 articles processed for cs
#   5210/20000 articles processed for cs
#   5220/20000 articles processed for cs
#   5230/20000 articles processed for cs
#   5240/20000 articles processed for cs
#   5250/20000 articles processed for cs
#   5260/20000 articles processed for cs
#   5270/20000 articles processed for cs
#   5280/20000 articles processed for cs
#   5290/20000 articles processed for cs
#   5300/20000 articles processed for cs
#   5310/20000 articles processed for cs
#   5320/20000 articles processed for cs
#   5330/20000 articles processed for cs
#   5340/20000 articles processed for cs
#   5350/20000 articles processed for cs
#   5360/20000 articles processed for cs
#   5370/20000 articles processed for cs
#   5380/20000 articles processed for cs
#   5390/20000 articles processed for cs
#   5400/20000 articles processed for cs
#   5410/20000 articles processed for cs
#   5420/20000 articles processed for cs
#   5430/20000 articles processed for cs
#   5440/20000 articles processed for cs
#   5450/20000 articles processed for cs
#   5460/20000 articles processed for cs
#   5470/20000 articles processed for cs
#   5480/20000 articles processed for cs
#   5490/20000 articles processed for cs
#   5500/20000 articles processed for cs
#   5510/20000 articles processed for cs
#   5520/20000 articles processed for cs
#   5530/20000 articles processed for cs
#   5540/20000 articles processed for cs
#   5550/20000 articles processed for cs
#   5560/20000 articles processed for cs
#   5570/20000 articles processed for cs
#   5580/20000 articles processed for cs
#   5590/20000 articles processed for cs
#   5600/20000 articles processed for cs
#   5610/20000 articles processed for cs
#   5620/20000 articles processed for cs
#   5630/20000 articles processed for cs
#   5640/20000 articles processed for cs
#   5650/20000 articles processed for cs
#   5660/20000 articles processed for cs
#   5670/20000 articles processed for cs
#   5680/20000 articles processed for cs
#   5690/20000 articles processed for cs
#   5700/20000 articles processed for cs
#   5710/20000 articles processed for cs
#   5720/20000 articles processed for cs
#   5730/20000 articles processed for cs
#   5740/20000 articles processed for cs
#   5750/20000 articles processed for cs
#   5760/20000 articles processed for cs
#   5770/20000 articles processed for cs
#   5780/20000 articles processed for cs
#   5790/20000 articles processed for cs
#   5800/20000 articles processed for cs
#   5810/20000 articles processed for cs
#   5820/20000 articles processed for cs
#   5830/20000 articles processed for cs
#   5840/20000 articles processed for cs
#   5850/20000 articles processed for cs
#   5860/20000 articles processed for cs
#   5870/20000 articles processed for cs
#   5880/20000 articles processed for cs
#   5890/20000 articles processed for cs
#   5900/20000 articles processed for cs
#   5910/20000 articles processed for cs
#   5920/20000 articles processed for cs
#   5930/20000 articles processed for cs
#   5940/20000 articles processed for cs
#   5950/20000 articles processed for cs
#   5960/20000 articles processed for cs
#   5970/20000 articles processed for cs
#   5980/20000 articles processed for cs
#   5990/20000 articles processed for cs
#   6000/20000 articles processed for cs
#   6010/20000 articles processed for cs
#   6020/20000 articles processed for cs
#   6030/20000 articles processed for cs
#   6040/20000 articles processed for cs
#   6050/20000 articles processed for cs
#   6060/20000 articles processed for cs
#   6070/20000 articles processed for cs
#   6080/20000 articles processed for cs
#   6090/20000 articles processed for cs
#   6100/20000 articles processed for cs
#   6110/20000 articles processed for cs
#   6120/20000 articles processed for cs
#   6130/20000 articles processed for cs
#   6140/20000 articles processed for cs
#   6150/20000 articles processed for cs
#   6160/20000 articles processed for cs
#   6170/20000 articles processed for cs
#   6180/20000 articles processed for cs
#   6190/20000 articles processed for cs
#   6200/20000 articles processed for cs
#   6210/20000 articles processed for cs
#   6220/20000 articles processed for cs
#   6230/20000 articles processed for cs
#   6240/20000 articles processed for cs
#   6250/20000 articles processed for cs
#   6260/20000 articles processed for cs
#   6270/20000 articles processed for cs
#   6280/20000 articles processed for cs
#   6290/20000 articles processed for cs
#   6300/20000 articles processed for cs
#   6310/20000 articles processed for cs
#   6320/20000 articles processed for cs
#   6330/20000 articles processed for cs
#   6340/20000 articles processed for cs
#   6350/20000 articles processed for cs
#   6360/20000 articles processed for cs
#   6370/20000 articles processed for cs
#   6380/20000 articles processed for cs
#   6390/20000 articles processed for cs
#   6400/20000 articles processed for cs
#   6410/20000 articles processed for cs
#   6420/20000 articles processed for cs
#   6430/20000 articles processed for cs
#   6440/20000 articles processed for cs
#   6450/20000 articles processed for cs
#   6460/20000 articles processed for cs
#   6470/20000 articles processed for cs
#   6480/20000 articles processed for cs
#   6490/20000 articles processed for cs
#   6500/20000 articles processed for cs
#   6510/20000 articles processed for cs
#   6520/20000 articles processed for cs
#   6530/20000 articles processed for cs
#   6540/20000 articles processed for cs
#   6550/20000 articles processed for cs
#   6560/20000 articles processed for cs
#   6570/20000 articles processed for cs
#   6580/20000 articles processed for cs
#   6590/20000 articles processed for cs
#   6600/20000 articles processed for cs
#   6610/20000 articles processed for cs
#   6620/20000 articles processed for cs
#   6630/20000 articles processed for cs
#   6640/20000 articles processed for cs
#   6650/20000 articles processed for cs
#   6660/20000 articles processed for cs
#   6670/20000 articles processed for cs
#   6680/20000 articles processed for cs
#   6690/20000 articles processed for cs
#   6700/20000 articles processed for cs
#   6710/20000 articles processed for cs
#   6720/20000 articles processed for cs
#   6730/20000 articles processed for cs
#   6740/20000 articles processed for cs
#   6750/20000 articles processed for cs
#   6760/20000 articles processed for cs
#   6770/20000 articles processed for cs
#   6780/20000 articles processed for cs
#   6790/20000 articles processed for cs
#   6800/20000 articles processed for cs
#   6810/20000 articles processed for cs
#   6820/20000 articles processed for cs
#   6830/20000 articles processed for cs
#   6840/20000 articles processed for cs
#   6850/20000 articles processed for cs
#   6860/20000 articles processed for cs
#   6870/20000 articles processed for cs
#   6880/20000 articles processed for cs
#   6890/20000 articles processed for cs
#   6900/20000 articles processed for cs
#   6910/20000 articles processed for cs
#   6920/20000 articles processed for cs
#   6930/20000 articles processed for cs
#   6940/20000 articles processed for cs
#   6950/20000 articles processed for cs
#   6960/20000 articles processed for cs
#   6970/20000 articles processed for cs
#   6980/20000 articles processed for cs
#   6990/20000 articles processed for cs
#   7000/20000 articles processed for cs
#   7010/20000 articles processed for cs
#   7020/20000 articles processed for cs
#   7030/20000 articles processed for cs
#   7040/20000 articles processed for cs
#   7050/20000 articles processed for cs
#   7060/20000 articles processed for cs
#   7070/20000 articles processed for cs
#   7080/20000 articles processed for cs
#   7090/20000 articles processed for cs
#   7100/20000 articles processed for cs
#   7110/20000 articles processed for cs
#   7120/20000 articles processed for cs
#   7130/20000 articles processed for cs
#   7140/20000 articles processed for cs
#   7150/20000 articles processed for cs
#   7160/20000 articles processed for cs
#   7170/20000 articles processed for cs
#   7180/20000 articles processed for cs
#   7190/20000 articles processed for cs
#   7200/20000 articles processed for cs
#   7210/20000 articles processed for cs
#   7220/20000 articles processed for cs
#   7230/20000 articles processed for cs
#   7240/20000 articles processed for cs
#   7250/20000 articles processed for cs
#   7260/20000 articles processed for cs
#   7270/20000 articles processed for cs
#   7280/20000 articles processed for cs
#   7290/20000 articles processed for cs
#   7300/20000 articles processed for cs
#   7310/20000 articles processed for cs
#   7320/20000 articles processed for cs
#   7330/20000 articles processed for cs
#   7340/20000 articles processed for cs
#   7350/20000 articles processed for cs
#   7360/20000 articles processed for cs
#   7370/20000 articles processed for cs
#   7380/20000 articles processed for cs
#   7390/20000 articles processed for cs
#   7400/20000 articles processed for cs
#   7410/20000 articles processed for cs
#   7420/20000 articles processed for cs
#   7430/20000 articles processed for cs
#   7440/20000 articles processed for cs
#   7450/20000 articles processed for cs
#   7460/20000 articles processed for cs
#   7470/20000 articles processed for cs
#   7480/20000 articles processed for cs
#   7490/20000 articles processed for cs
#   7500/20000 articles processed for cs
#   7510/20000 articles processed for cs
#   7520/20000 articles processed for cs
#   7530/20000 articles processed for cs
#   7540/20000 articles processed for cs
#   7550/20000 articles processed for cs
#   7560/20000 articles processed for cs
#   7570/20000 articles processed for cs
#   7580/20000 articles processed for cs
#   7590/20000 articles processed for cs
#   7600/20000 articles processed for cs
#   7610/20000 articles processed for cs
#   7620/20000 articles processed for cs
#   7630/20000 articles processed for cs
#   7640/20000 articles processed for cs
#   7650/20000 articles processed for cs
#   7660/20000 articles processed for cs
#   7670/20000 articles processed for cs
#   7680/20000 articles processed for cs
#   7690/20000 articles processed for cs
#   7700/20000 articles processed for cs
#   7710/20000 articles processed for cs
#   7720/20000 articles processed for cs
#   7730/20000 articles processed for cs
#   7740/20000 articles processed for cs
#   7750/20000 articles processed for cs
#   7760/20000 articles processed for cs
#   7770/20000 articles processed for cs
#   7780/20000 articles processed for cs
#   7790/20000 articles processed for cs
#   7800/20000 articles processed for cs
#   7810/20000 articles processed for cs
#   7820/20000 articles processed for cs
#   7830/20000 articles processed for cs
#   7840/20000 articles processed for cs
#   7850/20000 articles processed for cs
#   7860/20000 articles processed for cs
#   7870/20000 articles processed for cs
#   7880/20000 articles processed for cs
#   7890/20000 articles processed for cs
#   7900/20000 articles processed for cs
#   7910/20000 articles processed for cs
#   7920/20000 articles processed for cs
#   7930/20000 articles processed for cs
#   7940/20000 articles processed for cs
#   7950/20000 articles processed for cs
#   7960/20000 articles processed for cs
#   7970/20000 articles processed for cs
#   7980/20000 articles processed for cs
#   7990/20000 articles processed for cs
#   8000/20000 articles processed for cs
#   8010/20000 articles processed for cs
#   8020/20000 articles processed for cs
#   8030/20000 articles processed for cs
#   8040/20000 articles processed for cs
#   8050/20000 articles processed for cs
#   8060/20000 articles processed for cs
#   8070/20000 articles processed for cs
#   8080/20000 articles processed for cs
#   8090/20000 articles processed for cs
#   8100/20000 articles processed for cs
#   8110/20000 articles processed for cs
#   8120/20000 articles processed for cs
#   8130/20000 articles processed for cs
#   8140/20000 articles processed for cs
#   8150/20000 articles processed for cs
#   8160/20000 articles processed for cs
#   8170/20000 articles processed for cs
#   8180/20000 articles processed for cs
#   8190/20000 articles processed for cs
#   8200/20000 articles processed for cs
#   8210/20000 articles processed for cs
#   8220/20000 articles processed for cs
#   8230/20000 articles processed for cs
#   8240/20000 articles processed for cs
#   8250/20000 articles processed for cs
#   8260/20000 articles processed for cs
#   8270/20000 articles processed for cs
#   8280/20000 articles processed for cs
#   8290/20000 articles processed for cs
#   8300/20000 articles processed for cs
#   8310/20000 articles processed for cs
#   8320/20000 articles processed for cs
#   8330/20000 articles processed for cs
#   8340/20000 articles processed for cs
#   8350/20000 articles processed for cs
#   8360/20000 articles processed for cs
#   8370/20000 articles processed for cs
#   8380/20000 articles processed for cs
#   8390/20000 articles processed for cs
#   8400/20000 articles processed for cs
#   8410/20000 articles processed for cs
#   8420/20000 articles processed for cs
#   8430/20000 articles processed for cs
#   8440/20000 articles processed for cs
#   8450/20000 articles processed for cs
#   8460/20000 articles processed for cs
#   8470/20000 articles processed for cs
#   8480/20000 articles processed for cs
#   8490/20000 articles processed for cs
#   8500/20000 articles processed for cs
#   8510/20000 articles processed for cs
#   8520/20000 articles processed for cs
#   8530/20000 articles processed for cs
#   8540/20000 articles processed for cs
#   8550/20000 articles processed for cs
#   8560/20000 articles processed for cs
#   8570/20000 articles processed for cs
#   8580/20000 articles processed for cs
#   8590/20000 articles processed for cs
#   8600/20000 articles processed for cs
#   8610/20000 articles processed for cs
#   8620/20000 articles processed for cs
#   8630/20000 articles processed for cs
#   8640/20000 articles processed for cs
#   8650/20000 articles processed for cs
#   8660/20000 articles processed for cs
#   8670/20000 articles processed for cs
#   8680/20000 articles processed for cs
#   8690/20000 articles processed for cs
#   8700/20000 articles processed for cs
#   8710/20000 articles processed for cs
#   8720/20000 articles processed for cs
#   8730/20000 articles processed for cs
#   8740/20000 articles processed for cs
#   8750/20000 articles processed for cs
#   8760/20000 articles processed for cs
#   8770/20000 articles processed for cs
#   8780/20000 articles processed for cs
#   8790/20000 articles processed for cs
#   8800/20000 articles processed for cs
#   8810/20000 articles processed for cs
#   8820/20000 articles processed for cs
#   8830/20000 articles processed for cs
#   8840/20000 articles processed for cs
#   8850/20000 articles processed for cs
#   8860/20000 articles processed for cs
#   8870/20000 articles processed for cs
#   8880/20000 articles processed for cs
#   8890/20000 articles processed for cs
#   8900/20000 articles processed for cs
#   8910/20000 articles processed for cs
#   8920/20000 articles processed for cs
#   8930/20000 articles processed for cs
#   8940/20000 articles processed for cs
#   8950/20000 articles processed for cs
#   8960/20000 articles processed for cs
#   8970/20000 articles processed for cs
#   8980/20000 articles processed for cs
#   8990/20000 articles processed for cs
#   9000/20000 articles processed for cs
#   9010/20000 articles processed for cs
#   9020/20000 articles processed for cs
#   9030/20000 articles processed for cs
#   9040/20000 articles processed for cs
#   9050/20000 articles processed for cs
#   9060/20000 articles processed for cs
#   9070/20000 articles processed for cs
#   9080/20000 articles processed for cs
#   9090/20000 articles processed for cs
#   9100/20000 articles processed for cs
#   9110/20000 articles processed for cs
#   9120/20000 articles processed for cs
#   9130/20000 articles processed for cs
#   9140/20000 articles processed for cs
#   9150/20000 articles processed for cs
#   9160/20000 articles processed for cs
#   9170/20000 articles processed for cs
#   9180/20000 articles processed for cs
#   9190/20000 articles processed for cs
#   9200/20000 articles processed for cs
#   9210/20000 articles processed for cs
#   9220/20000 articles processed for cs
#   9230/20000 articles processed for cs
#   9240/20000 articles processed for cs
#   9250/20000 articles processed for cs
#   9260/20000 articles processed for cs
#   9270/20000 articles processed for cs
#   9280/20000 articles processed for cs
#   9290/20000 articles processed for cs
#   9300/20000 articles processed for cs
#   9310/20000 articles processed for cs
#   9320/20000 articles processed for cs
#   9330/20000 articles processed for cs
#   9340/20000 articles processed for cs
#   9350/20000 articles processed for cs
#   9360/20000 articles processed for cs
#   9370/20000 articles processed for cs
#   9380/20000 articles processed for cs
#   9390/20000 articles processed for cs
#   9400/20000 articles processed for cs
#   9410/20000 articles processed for cs
#   9420/20000 articles processed for cs
#   9430/20000 articles processed for cs
#   9440/20000 articles processed for cs
#   9450/20000 articles processed for cs
#   9460/20000 articles processed for cs
#   9470/20000 articles processed for cs
#   9480/20000 articles processed for cs
#   9490/20000 articles processed for cs
#   9500/20000 articles processed for cs
#   9510/20000 articles processed for cs
#   9520/20000 articles processed for cs
#   9530/20000 articles processed for cs
#   9540/20000 articles processed for cs
#   9550/20000 articles processed for cs
#   9560/20000 articles processed for cs
#   9570/20000 articles processed for cs
#   9580/20000 articles processed for cs
#   9590/20000 articles processed for cs
#   9600/20000 articles processed for cs
#   9610/20000 articles processed for cs
#   9620/20000 articles processed for cs
#   9630/20000 articles processed for cs
#   9640/20000 articles processed for cs
#   9650/20000 articles processed for cs
#   9660/20000 articles processed for cs
#   9670/20000 articles processed for cs
#   9680/20000 articles processed for cs
#   9690/20000 articles processed for cs
#   9700/20000 articles processed for cs
#   9710/20000 articles processed for cs
#   9720/20000 articles processed for cs
#   9730/20000 articles processed for cs
#   9740/20000 articles processed for cs
#   9750/20000 articles processed for cs
#   9760/20000 articles processed for cs
#   9770/20000 articles processed for cs
#   9780/20000 articles processed for cs
#   9790/20000 articles processed for cs
#   9800/20000 articles processed for cs
#   9810/20000 articles processed for cs
#   9820/20000 articles processed for cs
#   9830/20000 articles processed for cs
#   9840/20000 articles processed for cs
#   9850/20000 articles processed for cs
#   9860/20000 articles processed for cs
#   9870/20000 articles processed for cs
#   9880/20000 articles processed for cs
#   9890/20000 articles processed for cs
#   9900/20000 articles processed for cs
#   9910/20000 articles processed for cs
#   9920/20000 articles processed for cs
#   9930/20000 articles processed for cs
#   9940/20000 articles processed for cs
#   9950/20000 articles processed for cs
#   9960/20000 articles processed for cs
#   9970/20000 articles processed for cs
#   9980/20000 articles processed for cs
#   9990/20000 articles processed for cs
#   10000/20000 articles processed for cs
#   10010/20000 articles processed for cs
#   10020/20000 articles processed for cs
#   10030/20000 articles processed for cs
#   10040/20000 articles processed for cs
#   10050/20000 articles processed for cs
#   10060/20000 articles processed for cs
#   10070/20000 articles processed for cs
#   10080/20000 articles processed for cs
#   10090/20000 articles processed for cs
#   10100/20000 articles processed for cs
#   10110/20000 articles processed for cs
#   10120/20000 articles processed for cs
#   10130/20000 articles processed for cs
#   10140/20000 articles processed for cs
#   10150/20000 articles processed for cs
#   10160/20000 articles processed for cs
#   10170/20000 articles processed for cs
#   10180/20000 articles processed for cs
#   10190/20000 articles processed for cs
#   10200/20000 articles processed for cs
#   10210/20000 articles processed for cs
#   10220/20000 articles processed for cs
#   10230/20000 articles processed for cs
#   10240/20000 articles processed for cs
#   10250/20000 articles processed for cs
#   10260/20000 articles processed for cs
#   10270/20000 articles processed for cs
#   10280/20000 articles processed for cs
#   10290/20000 articles processed for cs
#   10300/20000 articles processed for cs
#   10310/20000 articles processed for cs
#   10320/20000 articles processed for cs
#   10330/20000 articles processed for cs
#   10340/20000 articles processed for cs
#   10350/20000 articles processed for cs
#   10360/20000 articles processed for cs
#   10370/20000 articles processed for cs
#   10380/20000 articles processed for cs
#   10390/20000 articles processed for cs
#   10400/20000 articles processed for cs
#   10410/20000 articles processed for cs
#   10420/20000 articles processed for cs
#   10430/20000 articles processed for cs
#   10440/20000 articles processed for cs
#   10450/20000 articles processed for cs
#   10460/20000 articles processed for cs
#   10470/20000 articles processed for cs
#   10480/20000 articles processed for cs
#   10490/20000 articles processed for cs
#   10500/20000 articles processed for cs
#   10510/20000 articles processed for cs
#   10520/20000 articles processed for cs
#   10530/20000 articles processed for cs
#   10540/20000 articles processed for cs
#   10550/20000 articles processed for cs
#   10560/20000 articles processed for cs
#   10570/20000 articles processed for cs
#   10580/20000 articles processed for cs
#   10590/20000 articles processed for cs
#   10600/20000 articles processed for cs
#   10610/20000 articles processed for cs
#   10620/20000 articles processed for cs
#   10630/20000 articles processed for cs
#   10640/20000 articles processed for cs
#   10650/20000 articles processed for cs
#   10660/20000 articles processed for cs
#   10670/20000 articles processed for cs
#   10680/20000 articles processed for cs
#   10690/20000 articles processed for cs
#   10700/20000 articles processed for cs
#   10710/20000 articles processed for cs
#   10720/20000 articles processed for cs
#   10730/20000 articles processed for cs
#   10740/20000 articles processed for cs
#   10750/20000 articles processed for cs
#   10760/20000 articles processed for cs
#   10770/20000 articles processed for cs
#   10780/20000 articles processed for cs
#   10790/20000 articles processed for cs
#   10800/20000 articles processed for cs
#   10810/20000 articles processed for cs
#   10820/20000 articles processed for cs
#   10830/20000 articles processed for cs
#   10840/20000 articles processed for cs
#   10850/20000 articles processed for cs
#   10860/20000 articles processed for cs
#   10870/20000 articles processed for cs
#   10880/20000 articles processed for cs
#   10890/20000 articles processed for cs
#   10900/20000 articles processed for cs
#   10910/20000 articles processed for cs
#   10920/20000 articles processed for cs
#   10930/20000 articles processed for cs
#   10940/20000 articles processed for cs
#   10950/20000 articles processed for cs
#   10960/20000 articles processed for cs
#   10970/20000 articles processed for cs
#   10980/20000 articles processed for cs
#   10990/20000 articles processed for cs
#   11000/20000 articles processed for cs
#   11010/20000 articles processed for cs
#   11020/20000 articles processed for cs
#   11030/20000 articles processed for cs
#   11040/20000 articles processed for cs
#   11050/20000 articles processed for cs
#   11060/20000 articles processed for cs
#   11070/20000 articles processed for cs
#   11080/20000 articles processed for cs
#   11090/20000 articles processed for cs
#   11100/20000 articles processed for cs
#   11110/20000 articles processed for cs
#   11120/20000 articles processed for cs
#   11130/20000 articles processed for cs
#   11140/20000 articles processed for cs
#   11150/20000 articles processed for cs
#   11160/20000 articles processed for cs
#   11170/20000 articles processed for cs
#   11180/20000 articles processed for cs
#   11190/20000 articles processed for cs
#   11200/20000 articles processed for cs
#   11210/20000 articles processed for cs
#   11220/20000 articles processed for cs
#   11230/20000 articles processed for cs
#   11240/20000 articles processed for cs
#   11250/20000 articles processed for cs
#   11260/20000 articles processed for cs
#   11270/20000 articles processed for cs
#   11280/20000 articles processed for cs
#   11290/20000 articles processed for cs
#   11300/20000 articles processed for cs
#   11310/20000 articles processed for cs
#   11320/20000 articles processed for cs
#   11330/20000 articles processed for cs
#   11340/20000 articles processed for cs
#   11350/20000 articles processed for cs
#   11360/20000 articles processed for cs
#   11370/20000 articles processed for cs
#   11380/20000 articles processed for cs
#   11390/20000 articles processed for cs
#   11400/20000 articles processed for cs
#   11410/20000 articles processed for cs
#   11420/20000 articles processed for cs
#   11430/20000 articles processed for cs
#   11440/20000 articles processed for cs
#   11450/20000 articles processed for cs
#   11460/20000 articles processed for cs
#   11470/20000 articles processed for cs
#   11480/20000 articles processed for cs
#   11490/20000 articles processed for cs
#   11500/20000 articles processed for cs
#   11510/20000 articles processed for cs
#   11520/20000 articles processed for cs
#   11530/20000 articles processed for cs
#   11540/20000 articles processed for cs
#   11550/20000 articles processed for cs
#   11560/20000 articles processed for cs
#   11570/20000 articles processed for cs
#   11580/20000 articles processed for cs
#   11590/20000 articles processed for cs
#   11600/20000 articles processed for cs
#   11610/20000 articles processed for cs
#   11620/20000 articles processed for cs
#   11630/20000 articles processed for cs
#   11640/20000 articles processed for cs
#   11650/20000 articles processed for cs
#   11660/20000 articles processed for cs
#   11670/20000 articles processed for cs
#   11680/20000 articles processed for cs
#   11690/20000 articles processed for cs
#   11700/20000 articles processed for cs
#   11710/20000 articles processed for cs
#   11720/20000 articles processed for cs
#   11730/20000 articles processed for cs
#   11740/20000 articles processed for cs
#   11750/20000 articles processed for cs
#   11760/20000 articles processed for cs
#   11770/20000 articles processed for cs
#   11780/20000 articles processed for cs
#   11790/20000 articles processed for cs
#   11800/20000 articles processed for cs
#   11810/20000 articles processed for cs
#   11820/20000 articles processed for cs
#   11830/20000 articles processed for cs
#   11840/20000 articles processed for cs
#   11850/20000 articles processed for cs
#   11860/20000 articles processed for cs
#   11870/20000 articles processed for cs
#   11880/20000 articles processed for cs
#   11890/20000 articles processed for cs
#   11900/20000 articles processed for cs
#   11910/20000 articles processed for cs
#   11920/20000 articles processed for cs
#   11930/20000 articles processed for cs
#   11940/20000 articles processed for cs
#   11950/20000 articles processed for cs
#   11960/20000 articles processed for cs
#   11970/20000 articles processed for cs
#   11980/20000 articles processed for cs
#   11990/20000 articles processed for cs
#   12000/20000 articles processed for cs
#   12010/20000 articles processed for cs
#   12020/20000 articles processed for cs
#   12030/20000 articles processed for cs
#   12040/20000 articles processed for cs
#   12050/20000 articles processed for cs
#   12060/20000 articles processed for cs
#   12070/20000 articles processed for cs
#   12080/20000 articles processed for cs
#   12090/20000 articles processed for cs
#   12100/20000 articles processed for cs
#   12110/20000 articles processed for cs
#   12120/20000 articles processed for cs
#   12130/20000 articles processed for cs
#   12140/20000 articles processed for cs
#   12150/20000 articles processed for cs
#   12160/20000 articles processed for cs
#   12170/20000 articles processed for cs
#   12180/20000 articles processed for cs
#   12190/20000 articles processed for cs
#   12200/20000 articles processed for cs
#   12210/20000 articles processed for cs
#   12220/20000 articles processed for cs
#   12230/20000 articles processed for cs
#   12240/20000 articles processed for cs
#   12250/20000 articles processed for cs
#   12260/20000 articles processed for cs
# ...
#   16030/20000 articles processed for cs
#   16040/20000 articles processed for cs
#   16050/20000 articles processed for cs
#   16060/20000 articles processed for cs
#   16070/20000 articles processed for cs
#   16080/20000 articles processed for cs
#   16090/20000 articles processed for cs
#   16100/20000 articles processed for cs
#   16110/20000 articles processed for cs
#   16120/20000 articles processed for cs
#   16130/20000 articles processed for cs
#   16140/20000 articles processed for cs
#   16150/20000 articles processed for cs
#   16160/20000 articles processed for cs
#   16170/20000 articles processed for cs
#   16180/20000 articles processed for cs
#   16190/20000 articles processed for cs
#   16200/20000 articles processed for cs
#   16210/20000 articles processed for cs
#   16220/20000 articles processed for cs
#   16230/20000 articles processed for cs
#   16240/20000 articles processed for cs
#   16250/20000 articles processed for cs
#   16260/20000 articles processed for cs
#   16270/20000 articles processed for cs
#   16280/20000 articles processed for cs
#   16290/20000 articles processed for cs
#   16300/20000 articles processed for cs
#   16310/20000 articles processed for cs
#   16320/20000 articles processed for cs
#   16330/20000 articles processed for cs
#   16340/20000 articles processed for cs
#   16350/20000 articles processed for cs
#   16360/20000 articles processed for cs
#   16370/20000 articles processed for cs
#   16380/20000 articles processed for cs
#   16390/20000 articles processed for cs
#   16400/20000 articles processed for cs
#   16410/20000 articles processed for cs
#   16420/20000 articles processed for cs
#   16430/20000 articles processed for cs
#   16440/20000 articles processed for cs
#   16450/20000 articles processed for cs
#   16460/20000 articles processed for cs
#   16470/20000 articles processed for cs
#   16480/20000 articles processed for cs
#   16490/20000 articles processed for cs
#   16500/20000 articles processed for cs
#   16510/20000 articles processed for cs
#   16520/20000 articles processed for cs
#   16530/20000 articles processed for cs
#   16540/20000 articles processed for cs
#   16550/20000 articles processed for cs
#   16560/20000 articles processed for cs
#   16570/20000 articles processed for cs
#   16580/20000 articles processed for cs
#   16590/20000 articles processed for cs
#   16600/20000 articles processed for cs
#   16610/20000 articles processed for cs
#   16620/20000 articles processed for cs
#   16630/20000 articles processed for cs
#   16640/20000 articles processed for cs
#   16650/20000 articles processed for cs
#   16660/20000 articles processed for cs
#   16670/20000 articles processed for cs
#   16680/20000 articles processed for cs
#   16690/20000 articles processed for cs
#   16700/20000 articles processed for cs
#   16710/20000 articles processed for cs
#   16720/20000 articles processed for cs
#   16730/20000 articles processed for cs
#   16740/20000 articles processed for cs
#   16750/20000 articles processed for cs
#   16760/20000 articles processed for cs
#   16770/20000 articles processed for cs
#   16780/20000 articles processed for cs
#   16790/20000 articles processed for cs
#   16800/20000 articles processed for cs
#   16810/20000 articles processed for cs
#   16820/20000 articles processed for cs
#   16830/20000 articles processed for cs
#   16840/20000 articles processed for cs
#   16850/20000 articles processed for cs
#   16860/20000 articles processed for cs
#   16870/20000 articles processed for cs
#   16880/20000 articles processed for cs
#   16890/20000 articles processed for cs
#   16900/20000 articles processed for cs
#   16910/20000 articles processed for cs
#   16920/20000 articles processed for cs
#   16930/20000 articles processed for cs
#   16940/20000 articles processed for cs
#   16950/20000 articles processed for cs
#   16960/20000 articles processed for cs
#   16970/20000 articles processed for cs
#   16980/20000 articles processed for cs
#   16990/20000 articles processed for cs
#   17000/20000 articles processed for cs
#   17010/20000 articles processed for cs
#   17020/20000 articles processed for cs
#   17030/20000 articles processed for cs
#   17040/20000 articles processed for cs
#   17050/20000 articles processed for cs
#   17060/20000 articles processed for cs
#   17070/20000 articles processed for cs
#   17080/20000 articles processed for cs
#   17090/20000 articles processed for cs
#   17100/20000 articles processed for cs
#   17110/20000 articles processed for cs
#   17120/20000 articles processed for cs
#   17130/20000 articles processed for cs
#   17140/20000 articles processed for cs
#   17150/20000 articles processed for cs
#   17160/20000 articles processed for cs
#   17170/20000 articles processed for cs
#   17180/20000 articles processed for cs
#   17190/20000 articles processed for cs
#   17200/20000 articles processed for cs
#   17210/20000 articles processed for cs
#   17220/20000 articles processed for cs
#   17230/20000 articles processed for cs
#   17240/20000 articles processed for cs
#   17250/20000 articles processed for cs
#   17260/20000 articles processed for cs
#   17270/20000 articles processed for cs
#   17280/20000 articles processed for cs
#   17290/20000 articles processed for cs
#   17300/20000 articles processed for cs
#   17310/20000 articles processed for cs
#   17320/20000 articles processed for cs
#   17330/20000 articles processed for cs
#   17340/20000 articles processed for cs
#   17350/20000 articles processed for cs
#   17360/20000 articles processed for cs
#   17370/20000 articles processed for cs
#   17380/20000 articles processed for cs
#   17390/20000 articles processed for cs
#   17400/20000 articles processed for cs
#   17410/20000 articles processed for cs
#   17420/20000 articles processed for cs
#   17430/20000 articles processed for cs
#   17440/20000 articles processed for cs
#   17450/20000 articles processed for cs
#   17460/20000 articles processed for cs
#   17470/20000 articles processed for cs
#   17480/20000 articles processed for cs
#   17490/20000 articles processed for cs
#   17500/20000 articles processed for cs
#   17510/20000 articles processed for cs
#   17520/20000 articles processed for cs
#   17530/20000 articles processed for cs
#   17540/20000 articles processed for cs
#   17550/20000 articles processed for cs
#   17560/20000 articles processed for cs
#   17570/20000 articles processed for cs
#   17580/20000 articles processed for cs
#   17590/20000 articles processed for cs
#   17600/20000 articles processed for cs
#   17610/20000 articles processed for cs
#   17620/20000 articles processed for cs
#   17630/20000 articles processed for cs
#   17640/20000 articles processed for cs
#   17650/20000 articles processed for cs
#   17660/20000 articles processed for cs
#   17670/20000 articles processed for cs
#   17680/20000 articles processed for cs
#   17690/20000 articles processed for cs
#   17700/20000 articles processed for cs
#   17710/20000 articles processed for cs
#   17720/20000 articles processed for cs
#   17730/20000 articles processed for cs
#   17740/20000 articles processed for cs
#   17750/20000 articles processed for cs
#   17760/20000 articles processed for cs
#   17770/20000 articles processed for cs
#   17780/20000 articles processed for cs
#   17790/20000 articles processed for cs
#   17800/20000 articles processed for cs
#   17810/20000 articles processed for cs
#   17820/20000 articles processed for cs
#   17830/20000 articles processed for cs
#   17840/20000 articles processed for cs
#   17850/20000 articles processed for cs
#   17860/20000 articles processed for cs
#   17870/20000 articles processed for cs
#   17880/20000 articles processed for cs
#   17890/20000 articles processed for cs
#   17900/20000 articles processed for cs
#   17910/20000 articles processed for cs
#   17920/20000 articles processed for cs
#   17930/20000 articles processed for cs
#   17940/20000 articles processed for cs
#   17950/20000 articles processed for cs
#   17960/20000 articles processed for cs
#   17970/20000 articles processed for cs
#   17980/20000 articles processed for cs
#   17990/20000 articles processed for cs
#   18000/20000 articles processed for cs
#   18010/20000 articles processed for cs
#   18020/20000 articles processed for cs
#   18030/20000 articles processed for cs
#   18040/20000 articles processed for cs
#   18050/20000 articles processed for cs
#   18060/20000 articles processed for cs
#   18070/20000 articles processed for cs
#   18080/20000 articles processed for cs
#   18090/20000 articles processed for cs
#   18100/20000 articles processed for cs
#   18110/20000 articles processed for cs
#   18120/20000 articles processed for cs
#   18130/20000 articles processed for cs
#   18140/20000 articles processed for cs
#   18150/20000 articles processed for cs
#   18160/20000 articles processed for cs
#   18170/20000 articles processed for cs
#   18180/20000 articles processed for cs
#   18190/20000 articles processed for cs
#   18200/20000 articles processed for cs
#   18210/20000 articles processed for cs
#   18220/20000 articles processed for cs
#   18230/20000 articles processed for cs
#   18240/20000 articles processed for cs
#   18250/20000 articles processed for cs
#   18260/20000 articles processed for cs
#   18270/20000 articles processed for cs
#   18280/20000 articles processed for cs
#   18290/20000 articles processed for cs
#   18300/20000 articles processed for cs
#   18310/20000 articles processed for cs
#   18320/20000 articles processed for cs
#   18330/20000 articles processed for cs
#   18340/20000 articles processed for cs
#   18350/20000 articles processed for cs
#   18360/20000 articles processed for cs
#   18370/20000 articles processed for cs
#   18380/20000 articles processed for cs
#   18390/20000 articles processed for cs
#   18400/20000 articles processed for cs
#   18410/20000 articles processed for cs
#   18420/20000 articles processed for cs
#   18430/20000 articles processed for cs
#   18440/20000 articles processed for cs
#   18450/20000 articles processed for cs
#   18460/20000 articles processed for cs
#   18470/20000 articles processed for cs
#   18480/20000 articles processed for cs
#   18490/20000 articles processed for cs
#   18500/20000 articles processed for cs
#   18510/20000 articles processed for cs
#   18520/20000 articles processed for cs
#   18530/20000 articles processed for cs
#   18540/20000 articles processed for cs
#   18550/20000 articles processed for cs
#   18560/20000 articles processed for cs
#   18570/20000 articles processed for cs
#   18580/20000 articles processed for cs
#   18590/20000 articles processed for cs
#   18600/20000 articles processed for cs
#   18610/20000 articles processed for cs
#   18620/20000 articles processed for cs
#   18630/20000 articles processed for cs
#   18640/20000 articles processed for cs
#   18650/20000 articles processed for cs
#   18660/20000 articles processed for cs
#   18670/20000 articles processed for cs
#   18680/20000 articles processed for cs
#   18690/20000 articles processed for cs
#   18700/20000 articles processed for cs
#   18710/20000 articles processed for cs
#   18720/20000 articles processed for cs
#   18730/20000 articles processed for cs
#   18740/20000 articles processed for cs
#   18750/20000 articles processed for cs
#   18760/20000 articles processed for cs
#   18770/20000 articles processed for cs
#   18780/20000 articles processed for cs
#   18790/20000 articles processed for cs
#   18800/20000 articles processed for cs
#   18810/20000 articles processed for cs
#   18820/20000 articles processed for cs
#   18830/20000 articles processed for cs
#   18840/20000 articles processed for cs
#   18850/20000 articles processed for cs
#   18860/20000 articles processed for cs
#   18870/20000 articles processed for cs
#   18880/20000 articles processed for cs
#   18890/20000 articles processed for cs
#   18900/20000 articles processed for cs
#   18910/20000 articles processed for cs
#   18920/20000 articles processed for cs
#   18930/20000 articles processed for cs
#   18940/20000 articles processed for cs
#   18950/20000 articles processed for cs
#   18960/20000 articles processed for cs
#   18970/20000 articles processed for cs
#   18980/20000 articles processed for cs
#   18990/20000 articles processed for cs
#   19000/20000 articles processed for cs
#   19010/20000 articles processed for cs
#   19020/20000 articles processed for cs
#   19030/20000 articles processed for cs
#   19040/20000 articles processed for cs
#   19050/20000 articles processed for cs
#   19060/20000 articles processed for cs
#   19070/20000 articles processed for cs
#   19080/20000 articles processed for cs
#   19090/20000 articles processed for cs
#   19100/20000 articles processed for cs
#   19110/20000 articles processed for cs
#   19120/20000 articles processed for cs
#   19130/20000 articles processed for cs
#   19140/20000 articles processed for cs
#   19150/20000 articles processed for cs
#   19160/20000 articles processed for cs
#   19170/20000 articles processed for cs
#   19180/20000 articles processed for cs
#   19190/20000 articles processed for cs
#   19200/20000 articles processed for cs
#   19210/20000 articles processed for cs
#   19220/20000 articles processed for cs
#   19230/20000 articles processed for cs
#   19240/20000 articles processed for cs
#   19250/20000 articles processed for cs
#   19260/20000 articles processed for cs
#   19270/20000 articles processed for cs
#   19280/20000 articles processed for cs
#   19290/20000 articles processed for cs
#   19300/20000 articles processed for cs
#   19310/20000 articles processed for cs
#   19320/20000 articles processed for cs
#   19330/20000 articles processed for cs
#   19340/20000 articles processed for cs
#   19350/20000 articles processed for cs
#   19360/20000 articles processed for cs
#   19370/20000 articles processed for cs
#   19380/20000 articles processed for cs
#   19390/20000 articles processed for cs
#   19400/20000 articles processed for cs
#   19410/20000 articles processed for cs
#   19420/20000 articles processed for cs
#   19430/20000 articles processed for cs
#   19440/20000 articles processed for cs
#   19450/20000 articles processed for cs
#   19460/20000 articles processed for cs
#   19470/20000 articles processed for cs
#   19480/20000 articles processed for cs
#   19490/20000 articles processed for cs
#   19500/20000 articles processed for cs
#   19510/20000 articles processed for cs
#   19520/20000 articles processed for cs
#   19530/20000 articles processed for cs
#   19540/20000 articles processed for cs
#   19550/20000 articles processed for cs
#   19560/20000 articles processed for cs
#   19570/20000 articles processed for cs
#   19580/20000 articles processed for cs
#   19590/20000 articles processed for cs
#   19600/20000 articles processed for cs
#   19610/20000 articles processed for cs
#   19620/20000 articles processed for cs
#   19630/20000 articles processed for cs
#   19640/20000 articles processed for cs
#   19650/20000 articles processed for cs
#   19660/20000 articles processed for cs
#   19670/20000 articles processed for cs
#   19680/20000 articles processed for cs
#   19690/20000 articles processed for cs
#   19700/20000 articles processed for cs
#   19710/20000 articles processed for cs
#   19720/20000 articles processed for cs
#   19730/20000 articles processed for cs
#   19740/20000 articles processed for cs
#   19750/20000 articles processed for cs
#   19760/20000 articles processed for cs
#   19770/20000 articles processed for cs
#   19780/20000 articles processed for cs
#   19790/20000 articles processed for cs
#   19800/20000 articles processed for cs
#   19810/20000 articles processed for cs
#   19820/20000 articles processed for cs
#   19830/20000 articles processed for cs
#   19840/20000 articles processed for cs
#   19850/20000 articles processed for cs
#   19860/20000 articles processed for cs
#   19870/20000 articles processed for cs
#   19880/20000 articles processed for cs
#   19890/20000 articles processed for cs
#   19900/20000 articles processed for cs
#   19910/20000 articles processed for cs
#   19920/20000 articles processed for cs
#   19930/20000 articles processed for cs
#   19940/20000 articles processed for cs
#   19950/20000 articles processed for cs
#   19960/20000 articles processed for cs
#   19970/20000 articles processed for cs
#   19980/20000 articles processed for cs
#   19990/20000 articles processed for cs
#   20000/20000 articles processed for cs
# Done for cs category with shape: (20000, 3)

# %%
final_df = pd.concat(list_articles_dfs, ignore_index=True)
print(final_df.shape)
final_df.head()
# Out:
# (20000, 3)
#            id                                              title  \
# 0  2301.00001                                             NFTrig
# 1  2301.00002  Evaluating Alternative Glyph Design for Showin...
# 2  2301.00003  Emotion in Cognitive Architecture: Emergent Pr...
# 3  2301.00005  Intrinsic Motivation in Dynamical Control Systems
# 4  2301.00006  Recovering Top-Two Answers and Confusion Proba...
#
#                                             abstract
# 0  NFTrig is a web-based application created for ...
# 1  We present experimental results to explore a f...
# 2  This document presents endeavors to represent ...
# 3  Biological systems often choose actions withou...
# 4  Crowdsourcing has emerged as an effective plat...

# %%
final_df.tail()
# Out:
#                id                                              title  \
# 19995  2301.00130  Accuracy-Guaranteed Collaborative DNN Inferenc...
# 19996  2301.00131  Guided Hybrid Quantization for Object detectio...
# 19997  2301.00134  Exploring the Use of Data-Driven Approaches fo...
# 19998  2301.00135  TeViS:Translating Text Synopses to Video Story...
# 19999  2301.00136      Power of Decision Trees with Monotone Queries
#
#                                                 abstract
# 19995  Collaboration among industrial Internet of Thi...
# 19996  Considering the computation complexity, we pro...
# 19997  The Internet of Things (IoT) is a system that ...
# 19998  A video storyboard is a roadmap for video crea...
# 19999  In this paper, we initiate study of the comput...

# %%
final_df.to_csv('arxiv_dataset.csv', index=False)
